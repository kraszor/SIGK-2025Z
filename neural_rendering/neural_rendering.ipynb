# %% [markdown]
# Phong Model

# %%
import json
import os

import torch
from PIL import Image
from torch.utils.data import Dataset
from torchvision import transforms


def split_dataset(split_ration, dataset_path):
    train_ratio, val_ratio, _ = split_ration
    total_size = len(os.listdir(os.path.join(dataset_path, "images")))
    indices = list(range(total_size))

    train_end = int(total_size * train_ratio)
    val_end = train_end + int(total_size * val_ratio)

    train_indices = indices[:train_end]
    val_indices = indices[train_end:val_end]
    test_indices = indices[val_end:]

    return train_indices, val_indices, test_indices


class PhongDataset(Dataset):
    def __init__(
        self,
        base_path,
        indices,
    ) -> None:
        self.image_path = os.path.join(base_path, "images")
        self.json_path = os.path.join(base_path, "params.json")
        self.transform = transforms.ToTensor()

        with open(self.json_path, "r") as f:
            all_samples = json.load(f)

        self.samples = [all_samples[i] for i in indices]

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sample = self.samples[idx]
        input_vec = (
            sample["model_translation_relative"]
            + sample["material_diffuse"]
            + [sample["material_shininess"]]
            + sample["light_position_relative"]
        )
        input_tensor = torch.tensor(input_vec, dtype=torch.float32)

        image = Image.open(
            os.path.join(self.image_path, sample["image_filename"])
        ).convert("RGB")
        target_tensor = self.transform(image)

        return input_tensor, target_tensor

# %%
# !pwd
# delete old repo
# !rm sigk -r
# clone new version of repo, main branch
# !git clone -b main https://github.com/kraszor/SIGK-2025Z.git
# Out:
# /content
# rm: cannot remove 'sigk': No such file or directory
# Cloning into 'SIGK-2025Z'...
# remote: Enumerating objects: 3219, done.
# remote: Counting objects: 100% (3219/3219), done.
# remote: Compressing objects: 100% (3173/3173), done.
# remote: Total 3219 (delta 98), reused 3120 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (3219/3219), 80.81 MiB | 10.77 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %% [markdown]
# Load datasets

# %%
from torch.utils.data import DataLoader
base_path = "/content/SIGK-2025Z/neural_rendering/output"
split_ratio = [0.6, 0.2, 0.2]
train_indices, val_indices, test_indices = split_dataset(split_ratio, base_path)
train_set = PhongDataset(base_path, train_indices)
val_set = PhongDataset(base_path, val_indices)
test_set = PhongDataset(base_path, test_indices)

batch_size = 32
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size)
test_loader = DataLoader(test_set, batch_size=batch_size)

# %% [markdown]
# Phong model

# %%
import torch
import torch.nn as nn

class Generator(nn.Module):
    def __init__(self, input_dim: int = 10, output_shape: tuple = (3, 128, 128)):
        super().__init__()
        self.output_shape = output_shape
        self.latent_size = 8

        self.fc = nn.Sequential(
            nn.Linear(input_dim, 1024),
            nn.ReLU(),
            nn.Linear(1024, 2048),
            nn.ReLU(),
            nn.Linear(2048, 256 * self.latent_size * self.latent_size),
            nn.ReLU()
        )

        self.upsample = nn.Sequential(
            nn.Upsample(scale_factor=2),
            nn.Conv2d(256, 128, 3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, 3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),

            nn.Upsample(scale_factor=2),
            nn.Conv2d(64, 32, 3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),

            nn.Upsample(scale_factor=2),
            nn.Conv2d(32, 3, 3, padding=1),
            nn.Tanh()
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.fc(x)
        x = x.view(-1, 256, self.latent_size, self.latent_size)
        return self.upsample(x)

class Discriminator(nn.Module):
    def __init__(self, input_channels: int = 3):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv2d(input_channels, 64, 4, stride=2, padding=1),  # 64x64
            nn.LeakyReLU(0.2),

            nn.Conv2d(64, 128, 4, stride=2, padding=1),  # 32x32
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),

            nn.Conv2d(128, 256, 4, stride=2, padding=1),  # 16x16
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),

            nn.Conv2d(256, 512, 4, stride=2, padding=1),  # 8x8
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),

            nn.Flatten(),
            nn.Linear(512 * 8 * 8, 1),
            nn.Sigmoid()
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.model(x)

# %% [markdown]
# Train phong model

# %% [markdown]
# Generator

# %%
import time

def validate(model, validation_loader, criterion, device, epoch=None):
    model.eval()
    total_loss = 0
    batch_count = 0
    start_time = time.time()

    with torch.no_grad():
        for input_image, target_image in validation_loader:
            input_image, target_image = input_image.to(device), target_image.to(device)

            output_image = model(input_image)
            loss = criterion(output_image, target_image)

            total_loss += loss.item()
            batch_count += 1

    avg_loss = total_loss / len(validation_loader)
    val_time = time.time() - start_time
    print(f"Epoch {epoch} Validation - Loss: {avg_loss:.6f}, "
                   f"Time: {val_time:.2f}s")

    return avg_loss

def train_generator(
    generator,
    train_dataloader,
    val_dataloader,
    criterion,
    optimizer,
    device,
    epochs
):
    print("START")
    patience = 5
    best_val_loss = float("inf")
    epochs_without_improvement = 0

    for epoch in range(epochs):
        epoch_loss = 0

        for input_image, target_image in train_dataloader:
            input_image, target_image = input_image.to(device), target_image.to(device)

            optimizer.zero_grad()
            output_image = generator(input_image)
            train_loss = criterion(output_image, target_image)

            train_loss.backward()
            optimizer.step()

            epoch_loss += train_loss.item()

        val_loss = validate(generator, val_dataloader, criterion, device, epoch)

        epoch_loss = epoch_loss/len(train_dataloader)
        print(f"Epoch {epoch + 1} Summary:")
        print(f"  Train Loss: {train_loss:.6f}")
        print(f"  Val Loss: {val_loss:.6f}")

        print("-" * 40)

    print("="*80)
    print("TRAINING COMPLETED")

    return generator

def train_discriminator(
    generator,
    discriminator,
    train_dataloader,
    val_dataloader,
    criterion,
    optimizer,
    device,
    epochs
):

    print("START")
    for epoch in range(epochs):
        epoch_loss = 0

        for input_image, target_image in train_dataloader:
            input_image, target_image = input_image.to(device), target_image.to(device)

            optimizer.zero_grad()
            # train discriminator
            real_labels = torch.full((batch_size, 1), 0.9, device=device)
            fake_labels = torch.full((batch_size, 1), 0.1, device=device)

            optimizer.zero_grad()
            real_prediction = discriminator(target_image)
            real_loss = adversarial_loss(real_prediction, real_labels)

            fake_images = generator(input_image).detach()
            fake_prediction = discriminator(fake_images)
            fake_loss = adversarial_loss(fake_prediction, fake_labels)

            train_loss = (real_loss + fake_loss) / 2
            train_loss.backward()
            optimizer.step()

            epoch_loss += train_loss.item()

        val_loss = validate(discriminator, val_dataloader, criterion, device, epoch)

        epoch_loss = epoch_loss/len(train_dataloader)
        print(f"Epoch {epoch + 1} Summary:")
        print(f"  Train Loss: {train_loss:.6f}")
        print(f"  Val Loss: {val_loss:.6f}")

        print("-" * 40)

    print("="*80)
    print("TRAINING COMPLETED")

    return discriminator


def train_gan(
  generator,
  discriminator,
  generator_optimizer,
  discriminator_optimizer,
  adversarial_loss,
  train_loader,
  val_loader,
  device,
  epochs: int = 20,
  lambda_l1: float = 100.0
):
  generator = generator.to(device)
  discriminator = discriminator.to(device)
  l1_loss = nn.L1Loss()

  print("START")
  patience = 20
  best_val_loss = float("inf")
  epochs_without_improvement = 0

  for epoch in range(epochs):
    generator.train()
    discriminator.train()
    G_loss_total = 0
    D_loss_total = 0

    for input_image, target_image in train_loader:
      input_image, target_image = input_image.to(device), target_image.to(device)
      batch_size = target_image.size(0)

      # train discriminator
      real_labels = torch.full((batch_size, 1), 0.9, device=device)
      fake_labels = torch.full((batch_size, 1), 0.1, device=device)

      discriminator_optimizer.zero_grad()
      real_prediction = discriminator(target_image)
      real_loss = adversarial_loss(real_prediction, real_labels)

      fake_images = generator(input_image).detach()
      fake_prediction = discriminator(fake_images)
      fake_loss = adversarial_loss(fake_prediction, fake_labels)

      loss_D = (real_loss + fake_loss) / 2
      loss_D.backward()
      discriminator_optimizer.step()

      # train generator
      generator_optimizer.zero_grad()
      gen_images = generator(input_image)
      preds = discriminator(gen_images)
      loss_G_adv = adversarial_loss(preds, real_labels)
      loss_G_l1 = l1_loss(gen_images, target_image)

      loss_G = loss_G_adv + lambda_l1 * loss_G_l1
      loss_G.backward()
      generator_optimizer.step()

      G_loss_total += loss_G.item()
      D_loss_total += loss_D.item()

    val_loss = validate(generator, val_loader, adversarial_loss, device, epoch)

    print(f"Epoch {epoch + 1} Summary:")
    print(f"  Generator Loss: {G_loss_total/len(train_loader):.4f}")
    print(f"  Discriminator Loss: {D_loss_total/len(train_loader):.4f}")

    print(f"  Validation Loss: {val_loss:.6f}")

    if val_loss < best_val_loss:
      improvement = best_val_loss - val_loss
      best_val_loss = val_loss
      epochs_without_improvement = 0
      model_filename = f"best_model"
      model_filename += ".pth"
      torch.save(generator.state_dict(), model_filename)
      print(f"  *** NEW BEST MODEL! Improvement: {improvement:.6f}")
      print(f"  Saved as: {model_filename}")

    else:
        epochs_without_improvement += 1
        print(f"  No improvement (best: {best_val_loss:.6f})")
        print(f"  Epochs without improvement: {epochs_without_improvement}/{patience}")

    # Early stopping check
    if epochs_without_improvement >= patience:
        print("="*80)
        print(f"EARLY STOPPING triggered after {epoch + 1} epochs")
        print(f"No improvement for {patience} consecutive epochs")
        print(f"Best validation loss: {best_val_loss:.6f}")
        print("="*80)
        break

    print("-" * 40)

# %%
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

generator = Generator()
discriminator = Discriminator()
generator = generator.to(device)
discriminator = discriminator.to(device)


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# train Gan
load_model = False


if not load_model:
  try:
    lr_G = 1e-4
    lr_D = 1e-5
    optimizer_G = optim.Adam(generator.parameters(), lr=lr_G, betas=(0.5, 0.999))
    optimizer_D = optim.Adam(discriminator.parameters(), lr=lr_G, betas=(0.5, 0.999))
    train_epochs=200
    warm_up_epochs = 10
    lambda_l1=100

    adversarial_loss = nn.MSELoss()

    torch.cuda.empty_cache()
    # Warm up generator
    print("WARM UP GENERATOR")
    generator = train_generator(generator, train_loader, val_loader, nn.MSELoss(), optimizer_G, device, warm_up_epochs)
    print("#"*40)
    print("TRAIN GAN")
    train_gan(generator, discriminator, optimizer_G, optimizer_D, adversarial_loss, train_loader, val_loader, device, train_epochs, lambda_l1)

  finally:
    BEST_LOCAL_PATH = 'best_model.pth' # Path where the first code block saved the file
    best_state_dict = torch.load(BEST_LOCAL_PATH, map_location=device)

    generator.load_state_dict(best_state_dict)
    print(f"Loaded best model parameters from {BEST_LOCAL_PATH}")

    SAVE_DIR = "/content/drive/MyDrive/SIGK/NeuralRendering/models"
    MODEL_FILENAME = 'best_generator.pth'
    SAVE_PATH = os.path.join(SAVE_DIR, MODEL_FILENAME)
    torch.save(generator.state_dict(), SAVE_PATH)
    print(f"Final best model state saved to {SAVE_PATH}")

else:
    print("LOADING MODEL")
    LOAD_PATH = '/content/drive/MyDrive/SIGK/NeuralRendering/models/best_generator.pth'
    state_dict = torch.load(LOAD_PATH, map_location=device)
    generator.load_state_dict(state_dict)
# Out:
# WARM UP GENERATOR
# START
# Epoch 0 Validation - Loss: 0.005344, Time: 0.43s
# Epoch 1 Summary:
#   Train Loss: 0.004216
#   Val Loss: 0.005344
# ----------------------------------------
# Epoch 1 Validation - Loss: 0.001133, Time: 0.44s
# Epoch 2 Summary:
#   Train Loss: 0.000954
#   Val Loss: 0.001133
# ----------------------------------------
# Epoch 2 Validation - Loss: 0.001080, Time: 0.43s
# Epoch 3 Summary:
#   Train Loss: 0.001283
#   Val Loss: 0.001080
# ----------------------------------------
# Epoch 3 Validation - Loss: 0.001065, Time: 0.43s
# Epoch 4 Summary:
#   Train Loss: 0.001228
#   Val Loss: 0.001065
# ----------------------------------------
# Epoch 4 Validation - Loss: 0.001057, Time: 0.43s
# Epoch 5 Summary:
#   Train Loss: 0.000709
#   Val Loss: 0.001057
# ----------------------------------------
# Epoch 5 Validation - Loss: 0.001059, Time: 0.43s
# Epoch 6 Summary:
#   Train Loss: 0.001303
#   Val Loss: 0.001059
# ----------------------------------------
# Epoch 6 Validation - Loss: 0.001049, Time: 0.46s
# Epoch 7 Summary:
#   Train Loss: 0.000698
#   Val Loss: 0.001049
# ----------------------------------------
# Epoch 7 Validation - Loss: 0.001048, Time: 0.42s
# Epoch 8 Summary:
#   Train Loss: 0.001115
#   Val Loss: 0.001048
# ----------------------------------------
# Epoch 8 Validation - Loss: 0.001045, Time: 0.42s
# Epoch 9 Summary:
#   Train Loss: 0.000848
#   Val Loss: 0.001045
# ----------------------------------------
# Epoch 9 Validation - Loss: 0.001045, Time: 0.43s
# Epoch 10 Summary:
#   Train Loss: 0.000927
#   Val Loss: 0.001045
# ----------------------------------------
# ================================================================================
# TRAINING COMPLETED
# ########################################
# TRAIN GAN
# START
# Epoch 0 Validation - Loss: 0.006697, Time: 0.43s
# Epoch 1 Summary:
#   Generator Loss: 3.5378
#   Discriminator Loss: 0.0212
#   Validation Loss: 0.006697
#   *** NEW BEST MODEL! Improvement: inf
#   Saved as: best_model.pth
# ----------------------------------------
# Epoch 1 Validation - Loss: 0.004585, Time: 0.43s
# Epoch 2 Summary:
#   Generator Loss: 1.4332
#   Discriminator Loss: 0.0242
#   Validation Loss: 0.004585
#   *** NEW BEST MODEL! Improvement: 0.002113
#   Saved as: best_model.pth
# ----------------------------------------
# Epoch 2 Validation - Loss: 0.001715, Time: 0.43s
# Epoch 3 Summary:
#   Generator Loss: 1.2928
#   Discriminator Loss: 0.0065
#   Validation Loss: 0.001715
#   *** NEW BEST MODEL! Improvement: 0.002870
#   Saved as: best_model.pth
# ----------------------------------------
# Epoch 3 Validation - Loss: 0.001549, Time: 0.43s
# Epoch 4 Summary:
#   Generator Loss: 1.2439
#   Discriminator Loss: 0.0077
#   Validation Loss: 0.001549
#   *** NEW BEST MODEL! Improvement: 0.000166
#   Saved as: best_model.pth
# ----------------------------------------
# Epoch 4 Validation - Loss: 0.001954, Time: 0.42s
# Epoch 5 Summary:
#   Generator Loss: 1.2110
#   Discriminator Loss: 0.0044
#   Validation Loss: 0.001954
#   No improvement (best: 0.001549)
#   Epochs without improvement: 1/20
# ----------------------------------------
# Epoch 5 Validation - Loss: 0.004081, Time: 0.44s
# Epoch 6 Summary:
#   Generator Loss: 1.2367
#   Discriminator Loss: 0.0053
#   Validation Loss: 0.004081
#   No improvement (best: 0.001549)
#   Epochs without improvement: 2/20
# ----------------------------------------
# Epoch 6 Validation - Loss: 0.002035, Time: 0.43s
# Epoch 7 Summary:
#   Generator Loss: 1.2476
#   Discriminator Loss: 0.0085
#   Validation Loss: 0.002035
#   No improvement (best: 0.001549)
#   Epochs without improvement: 3/20
# ----------------------------------------
# Epoch 7 Validation - Loss: 0.001476, Time: 0.43s
# Epoch 8 Summary:
#   Generator Loss: 1.1376
#   Discriminator Loss: 0.0053
#   Validation Loss: 0.001476
#   *** NEW BEST MODEL! Improvement: 0.000074
#   Saved as: best_model.pth
# ----------------------------------------
# Epoch 8 Validation - Loss: 0.001681, Time: 0.44s
# Epoch 9 Summary:
#   Generator Loss: 1.0945
#   Discriminator Loss: 0.0031
#   Validation Loss: 0.001681
#   No improvement (best: 0.001476)
#   Epochs without improvement: 1/20
# ----------------------------------------
# Epoch 9 Validation - Loss: 0.001684, Time: 0.43s
# Epoch 10 Summary:
#   Generator Loss: 1.1076
#   Discriminator Loss: 0.0038
#   Validation Loss: 0.001684
#   No improvement (best: 0.001476)
#   Epochs without improvement: 2/20
# ----------------------------------------
# Epoch 10 Validation - Loss: 0.001816, Time: 0.43s
# Epoch 11 Summary:
#   Generator Loss: 1.2099
#   Discriminator Loss: 0.0113
#   Validation Loss: 0.001816
#   No improvement (best: 0.001476)
#   Epochs without improvement: 3/20
# ----------------------------------------
# Epoch 11 Validation - Loss: 0.001668, Time: 0.43s
# Epoch 12 Summary:
#   Generator Loss: 1.1458
#   Discriminator Loss: 0.0050
#   Validation Loss: 0.001668
#   No improvement (best: 0.001476)
#   Epochs without improvement: 4/20
# ----------------------------------------
# Epoch 12 Validation - Loss: 0.001775, Time: 0.43s
# Epoch 13 Summary:
#   Generator Loss: 1.1282
#   Discriminator Loss: 0.0046
#   Validation Loss: 0.001775
#   No improvement (best: 0.001476)
#   Epochs without improvement: 5/20
# ----------------------------------------
# Epoch 13 Validation - Loss: 0.001671, Time: 0.43s
# Epoch 14 Summary:
#   Generator Loss: 1.1346
#   Discriminator Loss: 0.0043
#   Validation Loss: 0.001671
#   No improvement (best: 0.001476)
#   Epochs without improvement: 6/20
# ----------------------------------------
# Epoch 14 Validation - Loss: 0.002026, Time: 0.43s
# Epoch 15 Summary:
#   Generator Loss: 1.1256
#   Discriminator Loss: 0.0123
#   Validation Loss: 0.002026
#   No improvement (best: 0.001476)
#   Epochs without improvement: 7/20
# ----------------------------------------
# Epoch 15 Validation - Loss: 0.001457, Time: 0.44s
# Epoch 16 Summary:
#   Generator Loss: 1.1513
#   Discriminator Loss: 0.0046
#   Validation Loss: 0.001457
#   *** NEW BEST MODEL! Improvement: 0.000019
#   Saved as: best_model.pth
# ----------------------------------------
# Epoch 16 Validation - Loss: 0.001946, Time: 0.43s
# Epoch 17 Summary:
#   Generator Loss: 1.1552
#   Discriminator Loss: 0.0054
#   Validation Loss: 0.001946
#   No improvement (best: 0.001457)
#   Epochs without improvement: 1/20
# ----------------------------------------
# Epoch 17 Validation - Loss: 0.001722, Time: 0.43s
# Epoch 18 Summary:
#   Generator Loss: 1.1257
#   Discriminator Loss: 0.0041
#   Validation Loss: 0.001722
#   No improvement (best: 0.001457)
#   Epochs without improvement: 2/20
# ----------------------------------------
# Epoch 18 Validation - Loss: 0.001698, Time: 0.43s
# Epoch 19 Summary:
#   Generator Loss: 1.0911
#   Discriminator Loss: 0.0039
#   Validation Loss: 0.001698
#   No improvement (best: 0.001457)
#   Epochs without improvement: 3/20
# ----------------------------------------
# Epoch 19 Validation - Loss: 0.001454, Time: 0.44s
# Epoch 20 Summary:
#   Generator Loss: 1.1367
#   Discriminator Loss: 0.0098
#   Validation Loss: 0.001454
#   *** NEW BEST MODEL! Improvement: 0.000003
#   Saved as: best_model.pth
# ----------------------------------------
# Epoch 20 Validation - Loss: 0.004501, Time: 0.43s
# Epoch 21 Summary:
#   Generator Loss: 1.2009
#   Discriminator Loss: 0.0109
#   Validation Loss: 0.004501
#   No improvement (best: 0.001454)
#   Epochs without improvement: 1/20
# ----------------------------------------
# Epoch 21 Validation - Loss: 0.001329, Time: 0.43s
# Epoch 22 Summary:
#   Generator Loss: 1.1818
#   Discriminator Loss: 0.0087
#   Validation Loss: 0.001329
#   *** NEW BEST MODEL! Improvement: 0.000125
#   Saved as: best_model.pth
# ----------------------------------------
# Epoch 22 Validation - Loss: 0.001845, Time: 0.45s
# Epoch 23 Summary:
#   Generator Loss: 1.1269
#   Discriminator Loss: 0.0059
#   Validation Loss: 0.001845
#   No improvement (best: 0.001329)
#   Epochs without improvement: 1/20
# ----------------------------------------
# Epoch 23 Validation - Loss: 0.001460, Time: 0.43s
# Epoch 24 Summary:
#   Generator Loss: 1.1380
#   Discriminator Loss: 0.0040
#   Validation Loss: 0.001460
#   No improvement (best: 0.001329)
#   Epochs without improvement: 2/20
# ----------------------------------------
# Epoch 24 Validation - Loss: 0.003301, Time: 0.43s
# Epoch 25 Summary:
#   Generator Loss: 1.1578
#   Discriminator Loss: 0.0040
#   Validation Loss: 0.003301
#   No improvement (best: 0.001329)
#   Epochs without improvement: 3/20
# ----------------------------------------
# Epoch 25 Validation - Loss: 0.001532, Time: 0.43s
# Epoch 26 Summary:
#   Generator Loss: 1.1376
#   Discriminator Loss: 0.0060
#   Validation Loss: 0.001532
#   No improvement (best: 0.001329)
#   Epochs without improvement: 4/20
# ----------------------------------------
# Epoch 26 Validation - Loss: 0.001577, Time: 0.43s
# Epoch 27 Summary:
#   Generator Loss: 1.0942
#   Discriminator Loss: 0.0021
#   Validation Loss: 0.001577
#   No improvement (best: 0.001329)
#   Epochs without improvement: 5/20
# ----------------------------------------
# Epoch 27 Validation - Loss: 0.001878, Time: 0.43s
# Epoch 28 Summary:
#   Generator Loss: 1.1835
#   Discriminator Loss: 0.0166
#   Validation Loss: 0.001878
#   No improvement (best: 0.001329)
#   Epochs without improvement: 6/20
# ----------------------------------------
# Epoch 28 Validation - Loss: 0.001608, Time: 0.43s
# Epoch 29 Summary:
#   Generator Loss: 1.1788
#   Discriminator Loss: 0.0102
#   Validation Loss: 0.001608
#   No improvement (best: 0.001329)
#   Epochs without improvement: 7/20
# ----------------------------------------
# Epoch 29 Validation - Loss: 0.001763, Time: 0.42s
# Epoch 30 Summary:
#   Generator Loss: 1.1824
#   Discriminator Loss: 0.0107
#   Validation Loss: 0.001763
#   No improvement (best: 0.001329)
#   Epochs without improvement: 8/20
# ----------------------------------------
# Epoch 30 Validation - Loss: 0.001852, Time: 0.43s
# Epoch 31 Summary:
#   Generator Loss: 1.1934
#   Discriminator Loss: 0.0114
#   Validation Loss: 0.001852
#   No improvement (best: 0.001329)
#   Epochs without improvement: 9/20
# ----------------------------------------
# Epoch 31 Validation - Loss: 0.001226, Time: 0.43s
# Epoch 32 Summary:
#   Generator Loss: 1.1848
#   Discriminator Loss: 0.0117
#   Validation Loss: 0.001226
#   *** NEW BEST MODEL! Improvement: 0.000103
#   Saved as: best_model.pth
# ----------------------------------------
# Epoch 32 Validation - Loss: 0.001271, Time: 0.43s
# Epoch 33 Summary:
#   Generator Loss: 1.0819
#   Discriminator Loss: 0.0075
#   Validation Loss: 0.001271
#   No improvement (best: 0.001226)
#   Epochs without improvement: 1/20
# ----------------------------------------
# Epoch 33 Validation - Loss: 0.001294, Time: 0.44s
# Epoch 34 Summary:
#   Generator Loss: 0.9481
#   Discriminator Loss: 0.0031
#   Validation Loss: 0.001294
#   No improvement (best: 0.001226)
#   Epochs without improvement: 2/20
# ----------------------------------------
# Epoch 34 Validation - Loss: 0.001482, Time: 0.43s
# Epoch 35 Summary:
#   Generator Loss: 0.9485
#   Discriminator Loss: 0.0018
#   Validation Loss: 0.001482
#   No improvement (best: 0.001226)
#   Epochs without improvement: 3/20
# ----------------------------------------
# Epoch 35 Validation - Loss: 0.001319, Time: 0.44s
# Epoch 36 Summary:
#   Generator Loss: 0.9907
#   Discriminator Loss: 0.0027
#   Validation Loss: 0.001319
#   No improvement (best: 0.001226)
#   Epochs without improvement: 4/20
# ----------------------------------------
# Epoch 36 Validation - Loss: 0.001607, Time: 0.44s
# Epoch 37 Summary:
#   Generator Loss: 1.0885
#   Discriminator Loss: 0.0075
#   Validation Loss: 0.001607
#   No improvement (best: 0.001226)
#   Epochs without improvement: 5/20
# ----------------------------------------
# Epoch 37 Validation - Loss: 0.001440, Time: 0.43s
# Epoch 38 Summary:
#   Generator Loss: 0.9980
#   Discriminator Loss: 0.0023
#   Validation Loss: 0.001440
#   No improvement (best: 0.001226)
#   Epochs without improvement: 6/20
# ----------------------------------------
# Epoch 38 Validation - Loss: 0.001501, Time: 0.43s
# Epoch 39 Summary:
#   Generator Loss: 0.9910
#   Discriminator Loss: 0.0019
#   Validation Loss: 0.001501
#   No improvement (best: 0.001226)
#   Epochs without improvement: 7/20
# ----------------------------------------
# Epoch 39 Validation - Loss: 0.001390, Time: 0.44s
# Epoch 40 Summary:
#   Generator Loss: 0.9670
#   Discriminator Loss: 0.0011
#   Validation Loss: 0.001390
#   No improvement (best: 0.001226)
#   Epochs without improvement: 8/20
# ----------------------------------------
# Epoch 40 Validation - Loss: 0.001648, Time: 0.42s
# Epoch 41 Summary:
#   Generator Loss: 0.9723
#   Discriminator Loss: 0.0008
#   Validation Loss: 0.001648
#   No improvement (best: 0.001226)
#   Epochs without improvement: 9/20
# ----------------------------------------
# Epoch 41 Validation - Loss: 0.001490, Time: 0.43s
# Epoch 42 Summary:
#   Generator Loss: 0.9726
#   Discriminator Loss: 0.0011
#   Validation Loss: 0.001490
#   No improvement (best: 0.001226)
#   Epochs without improvement: 10/20
# ----------------------------------------
# Epoch 42 Validation - Loss: 0.001978, Time: 0.43s
# Epoch 43 Summary:
#   Generator Loss: 0.9952
#   Discriminator Loss: 0.0008
#   Validation Loss: 0.001978
#   No improvement (best: 0.001226)
#   Epochs without improvement: 11/20
# ----------------------------------------
# Epoch 43 Validation - Loss: 0.002120, Time: 0.43s
# Epoch 44 Summary:
#   Generator Loss: 1.0355
#   Discriminator Loss: 0.0014
#   Validation Loss: 0.002120
#   No improvement (best: 0.001226)
#   Epochs without improvement: 12/20
# ----------------------------------------
# Epoch 44 Validation - Loss: 0.001438, Time: 0.42s
# Epoch 45 Summary:
#   Generator Loss: 1.0594
#   Discriminator Loss: 0.0056
#   Validation Loss: 0.001438
#   No improvement (best: 0.001226)
#   Epochs without improvement: 13/20
# ----------------------------------------
# Epoch 45 Validation - Loss: 0.001235, Time: 0.42s
# Epoch 46 Summary:
#   Generator Loss: 1.2880
#   Discriminator Loss: 0.0218
#   Validation Loss: 0.001235
#   No improvement (best: 0.001226)
#   Epochs without improvement: 14/20
# ----------------------------------------
# Epoch 46 Validation - Loss: 0.001322, Time: 0.43s
# Epoch 47 Summary:
#   Generator Loss: 1.1211
#   Discriminator Loss: 0.0115
#   Validation Loss: 0.001322
#   No improvement (best: 0.001226)
#   Epochs without improvement: 15/20
# ----------------------------------------
# Epoch 47 Validation - Loss: 0.001264, Time: 0.44s
# Epoch 48 Summary:
#   Generator Loss: 1.0394
#   Discriminator Loss: 0.0070
#   Validation Loss: 0.001264
#   No improvement (best: 0.001226)
#   Epochs without improvement: 16/20
# ----------------------------------------
# Epoch 48 Validation - Loss: 0.001307, Time: 0.43s
# Epoch 49 Summary:
#   Generator Loss: 0.9457
#   Discriminator Loss: 0.0034
#   Validation Loss: 0.001307
#   No improvement (best: 0.001226)
#   Epochs without improvement: 17/20
# ----------------------------------------
# Epoch 49 Validation - Loss: 0.001859, Time: 0.42s
# Epoch 50 Summary:
#   Generator Loss: 1.0034
#   Discriminator Loss: 0.0033
#   Validation Loss: 0.001859
#   No improvement (best: 0.001226)
#   Epochs without improvement: 18/20
# ----------------------------------------
# Epoch 50 Validation - Loss: 0.001764, Time: 0.44s
# Epoch 51 Summary:
#   Generator Loss: 1.0611
#   Discriminator Loss: 0.0044
#   Validation Loss: 0.001764
#   No improvement (best: 0.001226)
#   Epochs without improvement: 19/20
# ----------------------------------------
# Epoch 51 Validation - Loss: 0.001542, Time: 0.43s
# Epoch 52 Summary:
#   Generator Loss: 1.0661
#   Discriminator Loss: 0.0049
#   Validation Loss: 0.001542
#   No improvement (best: 0.001226)
#   Epochs without improvement: 20/20
# ================================================================================
# EARLY STOPPING triggered after 52 epochs
# No improvement for 20 consecutive epochs
# Best validation loss: 0.001226
# ================================================================================
# Loaded best model parameters from best_model.pth
# Final best model state saved to /content/drive/MyDrive/SIGK/NeuralRendering/models/best_generator.pth

# %% [markdown]
# Visualize model

# %%
import matplotlib.pyplot as plt

def compare_images(generated, groundTruth, n=4):

    generated    = generated.permute(0, 2, 3, 1).cpu()
    groundTruth    = groundTruth.permute(0, 2, 3, 1).cpu()

    k = min(n, len(generated), len(groundTruth))
    for i in range(k):
        fig, axes = plt.subplots(1, 2, figsize=(12, 2))

        axes[0].imshow(generated[i].clip(0, 1).squeeze())
        axes[0].set_title("Generated")
        axes[0].axis("off")

        axes[1].imshow(groundTruth[i].clip(0, 1).squeeze())
        axes[1].set_title("Ground Truth")
        axes[1].axis("off")


        plt.tight_layout()
        plt.show()

# %%
n = 10
i = 0
for input_image, target_image in test_loader:
  if(i>n):
    break

  input_image, target_image = input_image.to(device), target_image.to(device)

  generator.eval()
  with torch.no_grad():
    generated = generator(input_image)

  compare_images(generated, target_image)
  i+=1

# %% [markdown]
# Metrics

# %%
# !pip install flip_evaluator
# Out:
# Collecting flip_evaluator
#   Downloading flip_evaluator-1.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Downloading flip_evaluator-1.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (415 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 415.2/415.2 kB 31.8 MB/s eta 0:00:00
# Installing collected packages: flip_evaluator
# Successfully installed flip_evaluator-1.7

# %%
# !pip install lpips
# Out:
# Collecting lpips
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.24.0+cu126)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.0.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.3)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.2.1->lpips) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.0->lpips) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: lpips
# Successfully installed lpips-0.1.4

# %%
import cv2
import flip_evaluator as flip
import lpips
import torch
import torch.nn as nn
from skimage.metrics import hausdorff_distance
from skimage.metrics import structural_similarity as ssim
from torch.utils.data import DataLoader
import numpy as np

def LPIPS(original, generated, device):
    lpips_loss_fn = lpips.LPIPS(net="vgg").to(device)
    device = next(lpips_loss_fn.parameters()).device
    #original = original.unsqueeze(0).to(device)
    #generated = generated.unsqueeze(0).to(device)
    lpips_val = lpips_loss_fn(original, generated)

    return lpips_val.mean().item()


def SSIM(original, generated):
    original_np = original.cpu().numpy()
    generated_np = generated.cpu().numpy()
    batch_scores = []

    for i in range(original_np.shape[0]):
        score, _ = ssim(
            original_np[i],
            generated_np[i], channel_axis=0, data_range=1.0, full=True
        )
        batch_scores.append(score)

    return torch.tensor(batch_scores).mean()


def FLIP(original, generated):
    original_np = original.detach().cpu().numpy()
    generated_np = generated.detach().cpu().numpy()
    batch_scores = []

    for i in range(original_np.shape[0]):
        _, mean_flip_error, _ = flip.evaluate(original_np[i], generated_np[i], "LDR")
        batch_scores.append(mean_flip_error)

    return torch.tensor(batch_scores).mean()



def hausdorff_distance_metric(original, generated):
    if torch.is_tensor(original):
        original = original.cpu().numpy()
    if torch.is_tensor(generated):
        generated = generated.cpu().numpy()

    if original.max() <= 1.0:
        original = (original * 255).astype("uint8")
    else:
        original = original.astype("uint8")

    if generated.max() <= 1.0:
        generated = (generated * 255).astype("uint8")
    else:
        generated = generated.astype("uint8")

    if len(original.shape) == 3:
        original = cv2.cvtColor(original, cv2.COLOR_RGB2GRAY)
    if len(generated.shape) == 3:
        generated = cv2.cvtColor(generated, cv2.COLOR_RGB2GRAY)
    t_lower = 50
    t_upper = 150
    edge_original = cv2.Canny(original, t_lower, t_upper)
    edge_generated = cv2.Canny(generated, t_lower, t_upper)
    return hausdorff_distance(edge_original, edge_generated)


def evaluate_SSIM(model: nn.Module, data: DataLoader, device: str):
    model.eval()
    total_score = 0
    num_batches = 0
    with torch.no_grad():
        for modified_img, original_img in data:
            modified_img, original_img = (
                modified_img.to(device),
                original_img.to(device),
            )
            generated_img = model(modified_img)

            score = SSIM(original_img, generated_img)
            total_score += score.item()
            num_batches += 1
    average_score = total_score / num_batches
    print(f"Average SSIM: {average_score:.4f}")
    return average_score


def evaluate_LPIPS(model: nn.Module, data: DataLoader, device: str):
    model.eval()
    total_score = 0
    num_batches = 0
    with torch.no_grad():
        for modified_img, original_img in data:
            modified_img, original_img = (
                modified_img.to(device),
                original_img.to(device),
            )
            generated_img = model(modified_img)
            score = LPIPS(original_img, generated_img, device)
            total_score += score
            num_batches += 1
    average_score = total_score / num_batches
    print(f"Average LPIPS: {average_score:.4f}")
    return average_score


def evaluete_FLIP(model: nn.Module, data: DataLoader, device: str):
    model.eval()
    total_score = 0
    num_batches = 0
    with torch.no_grad():
        for modified_img, original_img in data:
            modified_img, original_img = (
                modified_img.to(device),
                original_img.to(device),
            )
            generated_img = model(modified_img)
            score = FLIP(original_img, generated_img)
            total_score += score
            num_batches += 1
    average_score = total_score / num_batches
    print(f"Average FLIP: {average_score:.4f}")
    return average_score


def evaluate_hausdorff_distance(model: nn.Module, data: DataLoader, device: str):
    model.eval()
    total_distance = 0
    num_batches = 0
    with torch.no_grad():
        for modified_img, original_img in data:
            modified_img, original_img = (
                modified_img.to(device),
                original_img.to(device),
            )
            generated_img = model(modified_img)
            distance = hausdorff_distance_metric(original_img, generated_img)
            total_distance += distance
            num_batches += 1
    average_distance = total_distance / num_batches
    print(f"Average Hausdorff Distance: {average_distance:.4f}")
    return average_distance

# %%
avg_lpips = evaluate_LPIPS(generator, test_loader, device)
print(f"Avarage LPIPS: {avg_lpips}")
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Average LPIPS: 0.0963
# Avarage LPIPS: 0.0962584387314947

# %%
avg_hausdorff = evaluate_hausdorff_distance(generator, test_loader, device)
print(f"Avarage hausdorff: {avg_hausdorff}")
# Out:
# Average Hausdorff Distance: inf
# Avarage hausdorff: inf

# %%
avg_ssim = evaluate_SSIM(generator, test_loader, device)
print(f"Avarager SSIM: {avg_ssim}")
# Out:
# Average SSIM: 0.9803
# Avarager SSIM: 0.9802747682521218

# %%
avg_flip = evaluete_FLIP(generator, test_loader, device)
print(f"Avarager FLIP: {avg_flip}")
# Out:
# Average FLIP: 0.0081
# Avarager FLIP: 0.008088817819952965
